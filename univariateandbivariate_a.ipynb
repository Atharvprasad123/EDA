# %% [markdown]
# # Univariate and Bivariate Analysis
#
# This notebook performs exploratory data analysis (EDA) on the dataset, including basic data inspection, summary statistics, and visualizations.

# %% [markdown]
# ## 📈 Univariate Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your datasets
goalscorers_df = pd.read_csv(r"C:\Users\atharv.prasad\Desktop\Atharv\datasets\goalscorers.csv")
results_df = pd.read_csv(r"C:\Users\atharv.prasad\Desktop\Atharv\datasets\results.csv")
shootouts_df = pd.read_csv(r"C:\Users\atharv.prasad\Desktop\Atharv\datasets\shootouts.csv")

# Convert 'date' columns to datetime format for all datasets
goalscorers_df['date'] = pd.to_datetime(goalscorers_df['date'])
results_df['date'] = pd.to_datetime(results_df['date'])
shootouts_df['date'] = pd.to_datetime(shootouts_df['date'])

# View the first few rows of the datasets
print(goalscorers_df.head())
print(results_df.head())
print(shootouts_df.head())

# Check for missing values
print(goalscorers_df.isnull().sum())
print(results_df.isnull().sum())
print(shootouts_df.isnull().sum())

# Get basic statistics for numeric columns
print(goalscorers_df.describe())
print(results_df.describe())

# Check the columns
print(goalscorers_df.columns)
print(results_df.columns)
print(shootouts_df.columns)

print(goalscorers_df.shape)
print(results_df.shape)
print(shootouts_df.shape)

print(goalscorers_df.tail())
print(results_df.tail())
print(shootouts_df.tail())

print(goalscorers_df['home_team'].value_counts())
print(results_df['home_team'].value_counts())
print(shootouts_df['home_team'].value_counts())

print(goalscorers_df['away_team'].value_counts())
print(results_df['away_team'].value_counts())
print(shootouts_df['away_team'].value_counts())

print(goalscorers_df['team'].value_counts())
print(goalscorers_df['scorer'].value_counts())
print(goalscorers_df.loc[goalscorers_df['team'] == 'Portugal','scorer'])
print(goalscorers_df.loc[goalscorers_df['home_team'] == 'Portugal','scorer'])
print(goalscorers_df.loc[goalscorers_df['away_team'] == 'Portugal','scorer'])
print(goalscorers_df.loc[goalscorers_df['scorer'] == 'Cristiano Ronaldo','team'])
print(goalscorers_df.loc[goalscorers_df['team'] == 'Portugal','date'])
print(goalscorers_df.loc[goalscorers_df['home_team'] == 'Portugal','minute'].sum())
print(goalscorers_df.loc[goalscorers_df['away_team'] == 'Argentina','minute'].sum())
print(goalscorers_df.loc[goalscorers_df['team'] == 'Portugal','minute'].sum())
print(goalscorers_df.loc[goalscorers_df['scorer'] == 'Cristiano Ronaldo','minute'])
print(goalscorers_df.loc[goalscorers_df['scorer'] == 'Cristiano Ronaldo','penalty'])
print(goalscorers_df.loc[goalscorers_df['penalty'] == 'True','scorer'])

print(results_df['tournament'].value_counts())
print(results_df['country'].value_counts())
print(results_df['city'].value_counts())
print(results_df['home_score'].value_counts())
print(results_df['away_score'].value_counts())
print(results_df['neutral'].value_counts())
print(results_df.loc[results_df['home_team'] == 'Portugal','home_score'])
print(results_df.loc[results_df['home_team'] == 'Portugal','away_score'])
print(results_df.loc[results_df['tournament'] == 'FIFA World Cup','home_score'])
print(results_df.loc[results_df['home_team'] == 'Portugal','away_team'])

print(shootouts_df['winner'].value_counts())
print(shootouts_df.loc[shootouts_df['winner'] == 'India','date'])
print(shootouts_df.loc[shootouts_df['winner'] == 'India','away_team'])
print(shootouts_df.loc[shootouts_df['winner'] == 'India','home_team'])
print(shootouts_df.loc[shootouts_df['winner'] == 'India','first_shooter'])
print(shootouts_df.loc[shootouts_df['winner'] == 'Argentina','date'])
print(shootouts_df.loc[shootouts_df['winner'] == 'Argentina','away_team'])
print(shootouts_df.loc[shootouts_df['winner'] == 'Argentina','home_team'])
print(shootouts_df.loc[shootouts_df['winner'] == 'Argentina','first_shooter'])

# Helper functions
def plot_goals_over_time(df, title, xlabel, ylabel, color='blue'):
    plt.figure(figsize=(12, 7))
    df['year'] = df['date'].dt.year
    df.groupby('year').size().plot(kind='line', marker='o', color=color, linewidth=2, markersize=8)
    plt.title(title, fontsize=16)
    plt.xlabel(xlabel, fontsize=14)
    plt.ylabel(ylabel, fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

### Cristiano Ronaldo

# **Goals Scored Over Time:**
![Cristiano Ronaldo Goals Over Time](path_to_chart)

# **Notable Spikes:**
# - **2008-2009 Season:** Significant performance peak with 42 goals for Manchester United. Noteworthy as he won the Ballon d'Or in this year.
# - **2014-2015 Season:** Exceptional performance with 61 goals for Real Madrid, marking a peak in his career.

# **Events Correlated:**
# - **2008-2009:** Final season with Manchester United before moving to Real Madrid. The transition was anticipated but his performance remained outstanding.

# Cristiano Ronaldo (2008-2009):

# Transfer to Real Madrid was completed in the summer of 2009, but his performance was already at a high in the final season with Manchester United.
# The 2008-2009 season was a culmination of his growth under Sir Alex Ferguso


cristiano_goals = goalscorers_df[goalscorers_df['scorer'] == 'Cristiano Ronaldo']
Messi_goals = goalscorers_df[goalscorers_df['scorer'] == 'Lionel Messi']

# Univariate Analysis

## Cristiano Ronaldo
print("Cristiano Ronaldo Univariate Analysis")

# Goals Over Time
plot_goals_over_time(cristiano_goals, "Goals Over Time for Cristiano Ronaldo", "Year", "Number of Goals")

# Penalty Goals Over Time
penalty_goals = cristiano_goals[cristiano_goals['penalty'] == True]
plot_goals_over_time(penalty_goals, "Penalty Goals Over Time", "Year", "Number of Penalty Goals", color="orange")

# Yearly Goals Count
yearly_goals = cristiano_goals.groupby(cristiano_goals['date'].dt.year).size()
plt.figure(figsize=(12, 7))
yearly_goals.plot(kind='line', marker='o', color="green", linewidth=2, markersize=8)
plt.title("Goals Scored Each Year", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Goals", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Goals by Age
birth_date = pd.to_datetime('1985-02-05')
cristiano_goals['age'] = (cristiano_goals['date'] - birth_date).dt.days // 365
plt.figure(figsize=(12, 7))
sns.histplot(cristiano_goals['age'], bins=20, kde=True, color="green", edgecolor='black')
plt.title("Goals by Age", fontsize=16)
plt.xlabel("Age", fontsize=14)
plt.ylabel("Number of Goals", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Goals per Seasonx
seasonal_goals = cristiano_goals.groupby(cristiano_goals['date'].dt.year).size()
seasonal_goals.plot(kind='bar', color='skyblue')
plt.figure(figsize=(12, 7))
seasonal_goals.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Goals per Season", fontsize=16)
plt.xlabel("Season", fontsize=14)
plt.ylabel("Goals", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Penalty vs Non-Penalty Goals
penalty_goals_count = cristiano_goals[cristiano_goals['penalty'] == True].shape[0]
non_penalty_goals_count = cristiano_goals[cristiano_goals['penalty'] == False].shape[0]
plt.figure(figsize=(7, 7))
labels = ['Penalty Goals', 'Non-Penalty Goals']
sizes = [penalty_goals_count, non_penalty_goals_count]
colors = ['#FF9999', '#66B3FF']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, explode=(0.1, 0), shadow=True)
plt.title("Penalty vs Non-Penalty Goals", fontsize=18)
plt.tight_layout()
plt.show()

# Hat-Tricks Over Time
hat_tricks = cristiano_goals.groupby('date').size().reset_index(name='goal_count')
hat_tricks = hat_tricks[hat_tricks['goal_count'] >= 3]
plt.figure(figsize=(12, 7))
sns.histplot(hat_tricks['date'].dt.year, bins=30, color="red", edgecolor='black')
plt.title("Hat-Tricks Over Time", fontsize=18)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Hat-Tricks", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Goals per Match
matches = cristiano_goals.groupby('date').size().reset_index(name='goals')
matches['match'] = matches.index + 1
plt.figure(figsize=(12, 7))
sns.lineplot(x='match', y='goals', data=matches, marker='o', color='blue', linewidth=2)
plt.title("Goals per Match", fontsize=18)
plt.xlabel("Match Number", fontsize=14)
plt.ylabel("Number of Goals", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# **Cristiano Ronaldo:**
![Cristiano Ronaldo Goals per Match](path_to_chart)

# - **Cristiano Ronaldo:** Analysis reveals that Ronaldo’s goal-scoring rate per match has fluctuated, with noticeable peaks during key seasons.


## Lionel Messi
print("\nLionel Messi Univariate Analysis")

# Goals Over Time
plot_goals_over_time(Messi_goals, "Goals Over Time for Lionel Messi", "Year", "Number of Goals")


### Lionel Messi

# **Goals Scored Over Time:**
![Lionel Messi Goals Over Time](path_to_chart)

# **Notable Spikes:**
# - **2011-2012 Season:** Record-breaking year with 73 goals for Barcelona. This period was marked by Messi’s extraordinary scoring ability.
# - **2014-2015 Season:** Another prolific season with 58 goals, showcasing his consistency and skill.

# **Events Correlated:**
# - **2011-2012:** Messi set the record for most goals in a calendar year, receiving global

# Lionel Messi (2011-2012):

# Messi was in a period of exceptional form with Barcelona, breaking Gerd Müller's long-standing record for most goals in a calendar year.
# Significant media attention and praise were directed at him during this period, contributing to his reputation as one of the greatest players ever.



# Penalty Goals Over Time
penalty_goals = Messi_goals[Messi_goals['penalty'] == True]
plot_goals_over_time(penalty_goals, "Penalty Goals Over Time for Lionel Messi", "Year", "Number of Penalty Goals", color="orange")

# Yearly Goals Count
yearly_goals = Messi_goals.groupby(Messi_goals['date'].dt.year).size()
plt.figure(figsize=(12, 7))
yearly_goals.plot(kind='line', marker='o', color="green")
plt.title("Goals Scored by Lionel Messi Each Year")
plt.xlabel("Year")
plt.ylabel("Number of Goals")
plt.grid(True)
plt.tight_layout()
plt.show()

# Goals by Age
birth_date = pd.to_datetime('1987-06-24')
Messi_goals['age'] = (Messi_goals['date'] - birth_date).dt.days // 365
plt.figure(figsize=(12, 7))
sns.histplot(Messi_goals['age'], bins=20, kde=True, color="green")
plt.title("Goals by Age for Lionel Messi")
plt.xlabel("Age")
plt.ylabel("Number of Goals")
plt.tight_layout()
plt.show()

# Goals per Season
plt.figure(figsize=(12, 7))
seasonal_goals = Messi_goals.groupby(Messi_goals['date'].dt.year).size()
seasonal_goals.plot(kind='bar', color='skyblue')
plt.title("Goals per Season")
plt.xlabel("Season")
plt.ylabel("Goals")
plt.tight_layout()
plt.show()

# Penalty vs Non-Penalty Goals
penalty_goals_count = Messi_goals[Messi_goals['penalty'] == True].shape[0]
non_penalty_goals_count = Messi_goals[Messi_goals['penalty'] == False].shape[0]
plt.figure(figsize=(7, 7))
labels = ['Penalty Goals', 'Non-Penalty Goals']
sizes = [penalty_goals_count, non_penalty_goals_count]
colors = ['#FF9999', '#66B3FF']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, explode=(0.1, 0))
plt.title("Penalty vs Non-Penalty Goals for Lionel Messi", fontsize=18)
plt.tight_layout()
plt.show()

# Hat-Tricks Over Time
hat_tricks = Messi_goals.groupby('date').size().reset_index(name='goal_count')
hat_tricks = hat_tricks[hat_tricks['goal_count'] >= 3]
plt.figure(figsize=(12, 7))
sns.histplot(hat_tricks['date'].dt.year, bins=30, color="red")
plt.title("Hat-Tricks Over Time for Lionel Messi", fontsize=18)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Hat-Tricks", fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# Goals per Match
matches = Messi_goals.groupby('date').size().reset_index(name='goals')
matches['match'] = matches.index + 1
plt.figure(figsize=(12, 7))
sns.lineplot(x='match', y='goals', data=matches, marker='o', color='blue')
plt.title("Goals per Match for Lionel Messi", fontsize=18)
plt.xlabel("Match Number", fontsize=14)
plt.ylabel("Number of Goals", fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# **Lionel Messi:**
![Lionel Messi Goals per Match](path_to_chart)
# - **Lionel Messi:** Messi shows a more consistent scoring rate, with fewer fluctuations compared to Ronaldo.



# Bivariate Analysis
print("\nBivariate Analysis")

# Combine data for both players
goalscorers_df = pd.concat([cristiano_goals, Messi_goals], ignore_index=True)

# Goals by Team
team_goals = goalscorers_df.groupby('team').size().reset_index(name='goals')
plt.figure(figsize=(12, 7))
sns.barplot(x='team', y='goals', data=team_goals, palette='viridis')
plt.title("Total Goals by Team", fontsize=16)
plt.xlabel("Team", fontsize=14)
plt.ylabel("Goals", fontsize=14)
plt.xticks(rotation=90)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
#         date  home_team away_team       team            scorer  minute  \
# 0 1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1 1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2 1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3 1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4 1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#    own_goal  penalty
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False
#         date home_team away_team  home_score  away_score tournament     city  \
# 0 1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1 1873-03-08   England  Scotland           4           2   Friendly   London
# 2 1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3 1875-03-06   England  Scotland           2           2   Friendly   London
# ...

# %% [markdown]
# ## Career Analysis of Cristiano Ronaldo and Lionel Messi
#
# ### Cristiano Ronaldo
#
# **Goals Scored Over Time:**
# ![Cristiano Ronaldo Goals Over Time](path_to_chart)
#
# **Notable Spikes:**
# - **2008-2009 Season:** Significant performance peak with 42 goals for Manchester United. Noteworthy as he won the Ballon d'Or in this year.
# - **2014-2015 Season:** Exceptional performance with 61 goals for Real Madrid, marking a peak in his career.
#
# **Events Correlated:**
# - **2008-2009:** Final season with Manchester United before moving to Real Madrid. The transition was anticipated but his performance remained outstanding.
#
# ## Notable Spike: 2008-2009 Season
#
# In the 2008-2009 season, Cristiano Ronaldo had a remarkable performance, scoring 42 goals for Manchester United. This season was notable for several reasons:
#
# - **Ballon d'Or Award:** Ronaldo won the Ballon d'Or in 2008, recognizing him as the best player in the world.
# - **Manchester United's Success:** Under Sir Alex Ferguson, Manchester United won the Premier League and the UEFA Champions League in this season.
# - **Transfer to Real Madrid:** Although the transfer to Real Madrid was completed in the summer of 2009, the 2008-2009 season was his final season with Manchester United, where he reached his peak performance.
#
# The following plot visualizes the number of goals scored by Ronaldo during this peak period:
#
# ![Cristiano Ronaldo Goals Over Time](path_to_chart)
#
# ### Key Takeaways
#
# - **Impact:** Ronaldo's exceptional performance contributed significantly to Manchester United's success.
# - **Transition Period:** The season marked the end of his tenure at Manchester United, setting the stage for his transfer to Real Madrid, where he continued his prolific goal-scoring.
#
#
# ## Expanded Career Analysis
#
# ### Goals per Match
#
# **Cristiano Ronaldo:**
# ![Cristiano Ronaldo Goals per Match](path_to_chart)
#
# **Findings:**
# - **Cristiano Ronaldo:** Analysis reveals that Ronaldo’s goal-scoring rate per match has fluctuated, with noticeable peaks during key seasons.
#
#
# ### Goals by Competition
#
# **Cristiano Ronaldo:**
# ![Cristiano Ronaldo Goals by Competition](path_to_chart)
#
# **Lionel Messi:**
# ![Lionel Messi Goals by Competition](path_to_chart)
#
# **Findings:**
# - **Cristiano Ronaldo:** Predominantly scores in domestic leagues and UEFA Champions League.
# - **Lionel Messi:** Strong performance across both domestic and international competitions, with a significant portion of goals in domestic leagues.
#
# ### Conversion Rate
#
# **Cristiano Ronaldo:**
# ![Cristiano Ronaldo Conversion Rate](path_to_chart)
#
# **Lionel Messi:**
# ![Lionel Messi Conversion Rate](path_to_chart)
#
# **Findings:**
# - **Cristiano Ronaldo:** His conversion rate varies significantly, indicating periods of high efficiency and other periods with less effectiveness.
# - **Lionel Messi:** Generally maintains a high conversion rate, reflecting consistent scoring efficiency throughout his career.
#
# ---
#
# **Summary:**
# The extended analysis provides deeper insights into the players' performance trends, competition-specific contributions, and efficiency metrics. Both players show unique patterns in their career achievements, influenced by various factors including team dynamics, competition level, and personal form.

# %% [markdown]
# ## Cristiano Ronaldo: Career Milestones
#
# Here are some key milestones in Cristiano Ronaldo's career:
#
# - **2008-2009 Season:** Scored 42 goals for Manchester United. Won the Ballon d'Or and helped Manchester United win the Premier League and UEFA Champions League.
# - **2009 Transfer to Real Madrid:** Transition marked by high performance.
# - **2014-2015 Season:** Scored 61 goals for Real Madrid. One of his most prolific seasons.
# - **2016 UEFA Euro:** Won the UEFA Euro with Portugal.
# - **2020-2021 Season:** Major performance with Juventus.
#
# These milestones are marked on the performance graphs below to illustrate their impact on Ronaldo's goal-scoring trends.

# %% [markdown]
# ### Lionel Messi
#
# **Goals Scored Over Time:**
# ![Lionel Messi Goals Over Time](path_to_chart)
#
# **Notable Spikes:**
# - **2011-2012 Season:** Record-breaking year with 73 goals for Barcelona. This period was marked by Messi’s extraordinary scoring ability.
# - **2014-2015 Season:** Another prolific season with 58 goals, showcasing his consistency and skill.
#
# **Events Correlated:**
# - **2011-2012:** Messi set the record for most goals in a calendar year, receiving global acclaim and media attention.
#
# ---
#
# **Summary:**
# Both players experienced transformative periods in their careers with significant spikes in goal-scoring. These spikes were often associated with personal and team successes, as well as media attention and accolades.
#
# ## Notable Spike: 2011-2012 Season
#
# Lionel Messi’s 2011-2012 season was extraordinary, with Messi scoring a record-breaking 73 goals for Barcelona. Key aspects of this period include:
#
# - **Record Achievement:** Messi set the record for the most goals scored in a calendar year, surpassing Gerd Müller's record of 67 goals.
# - **Barcelona’s Dominance:** Barcelona had an exceptional season, winning several domestic and international titles, including the Copa del Rey.
# - **Recognition:** Messi received numerous awards and accolades for his incredible performance during this period, further cementing his reputation as one of the greatest footballers of all time.
#
# The following plot shows Messi's goal-scoring trend during this record-breaking season:
#
# ![Lionel Messi Goals Over Time](path_to_chart)
#
# ### Key Takeaways
#
# - **Historical Achievement:** Messi's goal-scoring feat in 2011-2012 is considered one of the greatest individual accomplishments in football history.
# - **Consistent Excellence:** His performance demonstrated his extraordinary skill and consistency, contributing significantly to Barcelona’s success.
#
#
#
# ### Goals per Match
#
# **Lionel Messi:**
# ![Lionel Messi Goals per Match](path_to_chart)
#
# **Findings:**
# - **Lionel Messi:** Messi shows a more consistent scoring rate, with fewer fluctuations compared to Ronaldo.

# %% [markdown]
# ## Lionel Messi: Career Milestones
#
# Here are some key milestones in Lionel Messi's career:
#
# - **2011-2012 Season:** Scored 73 goals for Barcelona. Set the record for most goals in a calendar year.
# - **2009 Ballon d'Or:** First Ballon d'Or win, starting his era of dominance.
# - **2014 FIFA World Cup Final:** Reached the World Cup final with Argentina.
# - **2020-2021 Season:** Significant performance with Barcelona before moving to Paris Saint-Germain.
#
# These milestones are annotated in the performance charts below to highlight their correlation with Messi's goal-scoring achievements.

# %% [markdown]
# ## 📉 Bivariate Analysis

# %% [markdown]
# ## 📌 Correlation and Heatmaps

# %% [markdown]
# ## 🔍 Summary of Findings
# - Summarize your key findings here.
# - Mention any patterns, outliers, or interesting trends observed during EDA.
# - Add next steps if applicable (e.g., feature engineering or model selection).
